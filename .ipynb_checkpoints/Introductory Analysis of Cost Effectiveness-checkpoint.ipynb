# %%
import pandas as pd
import numpy as np

wild_v_kazu = pd.read_csv("subset_for_analysis.csv")

# %%
wild_v_kazu['A]
# Out:
#    UNITID   OPEID  OPEID6                                     INSTNM  \
# 0  230764  367500    3675                         University of Utah
# 1  191241  272200    2722                         Fordham University
# 2  149231  175900    1759  Southern Illinois University-Edwardsville
#
#              CITY STABBR          INSTURL  \
# 0  Salt Lake City     UT     www.utah.edu
# 1           Bronx     NY  www.fordham.edu
# 2    Edwardsville     IL     www.siue.edu
#
#                                               NPCURL  HCM2  PREDDEG  ...  \
# 0  financialaid.utah.edu/tuition-and-fees/cost-ca...     0        3  ...
# 1                         www.fordham.edu/finaid/npc     0        3  ...
# 2         siue.studentaidcalculator.com/welcome.aspx     0        3  ...
#
#    PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  GT_25K_P6  GT_28K_P6  \
# 0    0.3268   0.2671            53000      0.727      0.706
# 1    0.5178   0.0696            59200      0.785      0.776
# 2    0.5746   0.1396            43000      0.706      0.677
#
#    GRAD_DEBT_MDN_SUPP  GRAD_DEBT_MDN10YR_SUPP  RPY_3YR_RT_SUPP  \
# 0               15000              159.465120         0.718053
# 1               26000              276.406208         0.765188
# 2               21434              227.865026         0.583843
#
#    C150_L4_POOLED_SUPP  C150_4_POOLED_SUPP
# 0                  NaN              0.6451
# 1                  NaN              0.8006
# 2                  NaN              0.4862
#
# [3 rows x 124 columns]

# %%
test_df = pd.DataFrame(wild_v_kazu['INSTNM'])

# %%
final_df = test_df.join(wild_v_kazu['NPT4_PRIV'])
final_df = final_df.join(wild_v_kazu['NPT4_PUB'])
final_df = final_df.join(wild_v_kazu['MD_EARN_WNE_P10'])
final_df = final_df.join(wild_v_kazu['GRAD_DEBT_MDN_SUPP'])
final_df
# Out:
#                                       INSTNM  NPT4_PRIV  NPT4_PUB  \
# 0                         University of Utah        NaN   12674.0
# 1                         Fordham University    35932.0       NaN
# 2  Southern Illinois University-Edwardsville        NaN   16304.0
#
#    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0            53000               15000
# 1            59200               26000
# 2            43000               21434

# %%
final_df.iloc[:,1:].fillna(0)
# Out:
#    NPT4_PRIV  NPT4_PUB  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0        0.0   12674.0            53000               15000
# 1    35932.0       0.0            59200               26000
# 2        0.0   16304.0            43000               21434

# %%
kazu_cost  = final_df.iloc[0,2]*4 
wild_cost  = final_df.iloc[1,1]*4 
phone_cost = final_df.iloc[2,2]*4

kazu_earnings = final_df.iloc[0,3]
wild_earnings = final_df.iloc[1,3]
phone_earnings= final_df.iloc[2,3]



cost_difference_percentage = round((phone_cost/kazu_cost),3)
earnings_difference_percentage = round((phone_earnings/kazu_earnings),3)


print(cost_difference_percentage,"%",sep="")
print(earnings_difference_percentage,"%",sep="")
# Well call these difference coeffecients and use them as weights
# Out:
# 1.286%
# 0.811%
